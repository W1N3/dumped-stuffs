# %%
# -*- coding: utf-8 -*-
#Primeiro Trabalho de Sistemas Operacionais I
#Professora: Valéria Bastos
#Grupo: Gabriel Silva - DRE 115192431
#		Matheus Gouvêa - DRE 
#		Thamires Bessa - DRE 113032431


#PCB - dicionário python
#filas de prioridades - listas
#fatia de tempo - 5ut
#número de processos - 10
#tempo de serviço - aleatório entre 0 e 100 - seguindo distribuição uniforme(0,100)
#tempos de I/O - Impressora: 15ut; Fita: 10ut; Disco: 1ut
#maximo de 5 pedidos de I/O por processo (aleatório entre 0 e 5)
#Filas: 4 filas, dessas 1 de alta prioridade, 1 de baixa prioridade, 2 de I/O que se dividem em: I/O longo e I/O curto

#PPID seria apenas pra identificar o pai de todos (8379) pelo qual é o primeiro processo a entrar na fila e possui tempo de serviço = 1ut

#Process Control Block será um dicionário para identificar o processo e suas características
#PCB
#	PID
#	PPID
#	STATUS (Executando, Pronto, Bloqueado, Pronto/Suspenso, Bloqueado/Suspenso)
#	PRIORIDADE (Alta, Baixa)
#	I/O [lista de IOs]

from collections import deque
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import datetime
import time
import ast

# Tempo de cada unidade de tempo em milissegundos
universal_ut = 0.05

# tabela hash com todos os processos, suas respectivas informações e o PCB
LOP = {}

# Filas cujo irão guardar a referência do processo na LOP
high_kiwi = []  # prioridade alta
low_kiwi = []  # prioridade baixa
io_kiwi = []  # IO ( no caso guarda uma tupla )

# variaveis de controle

# lista que guarda
# PID
# qual IO do processo está sendo realizado
# tempo realizado de IO até então
p_on_io = [0, 0, 0]

# guarda o PID do processo em execução
p_on_processor = 0


# temos os tempos fixos de duração de cada IO. O tempo de serviço de cada processo
# é aleatório, uniforme, entre 10 e 100 ut. A quantidade de IO que cada processo vai
# ter é aleatório, uniforme, entre 0 e 5. Dentro disso, temos que saber quando se darão
# essas saídas de IO, então resolvemos randomizar também. Ou seja, pegamos a quantidade de IOs
# aleatórias que foram sorteadas e sorteamos instantes dentro do tempo de serviço onde haverão
# saídas para IO.
def randomize_ios(service_time):
    types_of_io = ["D", "R", "M"]  # tempo de IO são respectivamente 1, 15 e 10
    # D = IO de Disco
    # R = IO de impRessora
    # M = IO de fita Magnetica
    list_of_ios = []
    num_of_ios = int(np.random.uniform(0, 5))
    for i in range(num_of_ios):
        io_type = types_of_io[int(np.random.uniform(0, 3))]
        io_p_time = int(np.random.uniform(0, service_time))
        list_of_ios.append((io_type, io_p_time))
    return list_of_ios


# na criação do processo, nós utilizamos um dicionário aninhado. O dicionário externo guarda
# as informações de tempo de serviço, tempos de IO e o PCB. O dicionário interno é o PCB.
# As filas de prioridade são 3, sendo elas: fila de prioridade alta, prioridade baixa e fila de IO.
# Para implementar o feedback no escalonamento faremos: Processos novos vão para fila de prioridade
# alta, processos retornando de IO seguem de acordo com o seu IO. Como nosso número de processos é finito
# e pequeno, não haverá starvation dos processos na fila de baixa prioridade porque eventualmente serão
# atendidos.
def create_process(next_pid):
    ts = int(np.random.uniform(10, 100))
    processo = {
        'tempo_de_chegada': int(np.random.uniform(0, 50)),
        'tempo_de_serviço': ts,
        'tempo_executado': 0,
        'IO': randomize_ios(ts),
        'PCB': {
            'PID': 6496 + next_pid,  # Definição do PID é sequencial a partir do pai de todos
            'PPID': 6495,  # pai de todos ( pela numerologia de pitagoras - ODIN )
            'Status': '',  # Executando (E), Pronto (P), Bloqueado (B), Terminado (T) - processos
            # recém criados vão automaticamente para fila de Prontos e durante sua execução terão seus estados alterados
            'Prioridade': 'A'  # Alta (A) e Baixa (B) - processos recém criados tem automaticamente prioridade alta
        }
    }
    return processo


# função que coloca o processo em execução no processador durante sua fatia de tempo
# ou até que seja despachado para IO
def schedule_next_process():
    global p_on_processor
    if (len(high_kiwi) > 0):
        p_on_processor = high_kiwi.popleft()
        if (LOP[p_on_processor]['PCB']['Status'] == 'P'):
            LOP[p_on_processor]['PCB']['Status'] = 'E'
            print("Processo " + str(p_on_processor) + " entrou em execução via AP")
    elif (len(low_kiwi) > 0):
        p_on_processor = low_kiwi.popleft()
        if (LOP[p_on_processor]['PCB']['Status'] == 'P'):
            LOP[p_on_processor]['PCB']['Status'] = 'E'
            print("Processo " + str(p_on_processor) + " entrou em execução via BP")
    else:
        p_on_processor = 0


# função que troca o estado de Executando para Pronto, Bloqueado ou Terminado
def unschedule_current_process(pid):
    if (LOP[pid]['tempo_executado'] < LOP[pid]['tempo_de_serviço']):
        # vai para Pronto caso não esteja na fila de IO e para a fila de baixa prioridade
        # vai para Bloqueado caso esteja na fila de IO e para a fila de alta prioridade
        is_io = False
        for i in range(len(io_kiwi)):
            if (io_kiwi[i][0] == pid and pid != p_on_io[0]):
                LOP[pid]['PCB']['Status'] = 'B'
                LOP[pid]['PCB']['Prioridade'] = 'A'
                io_type = LOP[pid]['IO'][io_kiwi[i][1]][0]
                is_io = True
                # Disco - retorna para a fila de baixa prioridade
                if (io_type == 'D'):
                    low_kiwi.append(pid)
                # Fita magnética e Impressora - retorna para a fila de alta prioridade;
                elif (io_type == 'R' or io_type == 'M'):
                    high_kiwi.append(pid)
                print("Processo " + str(pid) + " bloqueado")
            # Processos que sofreram preempção – retornam na fila de baixa prioridade
        if (is_io == False):
            LOP[pid]['PCB']['Status'] = 'P'
            LOP[pid]['PCB']['Prioridade'] = 'B'
            low_kiwi.append(pid)
            print("Processo " + str(pid) + " pronto")

    else:
        # vai para Terminado caso o tempo executado seja igual ao tempo de serviço
        LOP[pid]['PCB']['Status'] = 'T'
        print("Processo " + str(pid) + " terminado")


# Função para dispachar os processos para seus respectivos serviços de IO pelo tempo
# de duração estipulado para cada um deles
def dispatch_process_io(pid):
    for i in range(len(LOP[pid]['IO'])):
        if (LOP[pid]['IO'][i][1] == LOP[pid]['tempo_executado']):
            io_kiwi.append([pid, i, 0])
            print("Processo " + str(pid) + " colocou IO na fila")


# função que atualiza a fila de IO e escalona os processos para IO
def update_io_queue():
    global p_on_io
    if (p_on_io[0] == 0 and len(io_kiwi) > 0):
        p_on_io = io_kiwi.popleft()
    elif (p_on_io[0] != 0):
        # testar se o IO atual acabou
        io_type = LOP[p_on_io[0]]['IO'][p_on_io[1]][0]
        time_in_io = ord(io_type) - 67
        # verifica se o contador chegou no limite do tempo daquele tipo de IO
        if (p_on_io[2] >= time_in_io):
            LOP[p_on_io[0]]['PCB']['Status'] = 'B'
            # Disco - retorna para a fila de baixa prioridade
            if (io_type == 'D'):
                LOP[p_on_io[0]]['PCB']['Prioridade'] = 'B'
                low_kiwi.append(p_on_io[0])
            # Fita magnética e Impressora - retorna para a fila de alta prioridade;
            elif (io_type == 'R' or io_type == 'M'):
                LOP[p_on_io[0]]['PCB']['Prioridade'] = 'A'
                high_kiwi.append(p_on_io[0])

            if (len(io_kiwi) > 0):
                p_on_io = io_kiwi.popleft()
            else:
                p_on_io = [0, 0, 0]
        p_on_io[2] += 1


# função que atualiza o estado do processo dado o ciclo de clock
def step_current_process(pid):
    ret = False
    if (LOP[pid]['PCB']['Status'] == 'E'):
        for i in range(len(LOP[pid]['IO'])):
            if (LOP[pid]['IO'][i][1] == LOP[pid]['tempo_executado']):
                print("Processo " + str(pid) + " foi para IO")
                dispatch_process_io(pid)
                unschedule_current_process(pid)
                schedule_next_process()
                ret = True
        if (LOP[pid]['tempo_executado'] == LOP[pid]['tempo_de_serviço']):
            unschedule_current_process(pid)
            schedule_next_process()
            ret = True
        else:
            LOP[pid]['tempo_executado'] += 1
    return ret


# função que pega os processos iniciais e coloca na fila de alta prioridade
# Processos novos - entram na fila de alta prioridade
def check_arrival_time(c):
    for key in LOP:
        if (LOP[key]['tempo_de_chegada'] == c):
            LOP[key]['PCB']['Status'] = 'P'
            high_kiwi.append(LOP[key]['PCB']['PID'])
            print("Processo " + str(LOP[key]['PCB']['PID']) + " chegou")


# função que testa se todos os processos já terminaram
def test_services_times(pid):
    finished_counter = 0
    if (len(LOP) == 0):
        return False
    is_over = True
    for i in LOP:
        if (LOP[i]['tempo_de_serviço'] == LOP[i]['tempo_executado']):
            finished_counter += 1
    if (finished_counter == len(LOP)):
        is_over = False
    else:
        is_over = True
    return is_over


# faz o print de um vetor com o pid e o estado do processo

def log_status(c, d):
    log = None
    log = open('process-exec-' + str(d) + '.log', 'a')
    vec_to_print = '{'
    for i in LOP:
        vec_to_print += "'"+str(LOP[i]['PCB']['PID'])+"':'"+LOP[i]['PCB']['Status']+"',"
    ret = vec_to_print[:-1] + '}\n'
    log.write(ret)
    log.close()
    return ret

def log_processos(d):
    log = None
    log = open('process-info-' + str(d) + '.log', 'a')
    sum_of_info = '['
    for i in LOP:
        info_to_print = json.dumps(LOP[i]);
        sum_of_info += info_to_print + ','
        log.write(info_to_print + '\n')
    log.close()
    sum_of_info = sum_of_info[:-1]+ ']'
    return sum_of_info

if __name__ == "__main__":
    high_kiwi = deque([])
    low_kiwi = deque([])
    io_kiwi = deque([])
    log_data = []
    for i in range(0, 10):
        aux_p = create_process(i)
        LOP[aux_p['PCB']['PID']] = aux_p

    clock = 0
    hora = int(round(time.time()*1000))
    while (test_services_times(p_on_processor) == True):
        check_arrival_time(clock)
        if (p_on_processor == 0):
            schedule_next_process()
        else:
            already_scheduled = step_current_process(p_on_processor)
            update_io_queue()
            if ((clock % 5) == 0 and already_scheduled == False):
                unschedule_current_process(p_on_processor)
                schedule_next_process()
        #time.sleep(universal_ut)
        shit = log_status(clock, hora)
        log_data.append(ast.literal_eval(shit))
        clock += 1
    info = log_processos(hora)

###mágica do gráfico bonitinho
# gráfico para o dict de processos
    #log_data  = open('process-exec-' + str(hora) + '.log', 'r')
    
    log_data_df = pd.DataFrame.from_dict(log_data)
    status_filt = 'E'
    print(log_data_df)
        #print(sum_of_exec)
    new_data = []
    for elem in log_data:
        i = 0
        for key in elem:
            if elem[key] == 'E':
                i+=1
                new_data.append({'PID':int(key)-6495, 'clock': i}) 
    
    #log_data_df = pd.DataFrame.from_dict(new_data)
    #log_data_df.plot(kind='scatter',x='clock',y= 'PID',color='red')
    #plt.show()
# Out:
# Processo 6499 chegou
# Processo 6499 entrou em execução via AP
# Processo 6496 chegou
# Processo 6499 pronto
# Processo 6496 entrou em execução via AP
# Processo 6505 chegou
# Processo 6503 chegou
# Processo 6496 pronto
# Processo 6505 entrou em execução via AP
# Processo 6505 pronto
# Processo 6503 entrou em execução via AP
# Processo 6502 chegou
# Processo 6503 pronto
# Processo 6502 entrou em execução via AP
# Processo 6502 foi para IO
# Processo 6502 colocou IO na fila
# Processo 6502 bloqueado
# Processo 6502 pronto
# Processo 6499 entrou em execução via BP
# Processo 6504 chegou
# Processo 6500 chegou
# Processo 6499 pronto
# Processo 6504 entrou em execução via AP
# Processo 6497 chegou
# Processo 6504 pronto
# Processo 6500 entrou em execução via AP
# Processo 6500 pronto
# Processo 6497 entrou em execução via AP
# Processo 6498 chegou
# Processo 6501 chegou
# Processo 6497 pronto
# Processo 6502 pronto
# Processo 6498 entrou em execução via AP
# Processo 6498 foi para IO
# Processo 6498 colocou IO na fila
# Processo 6498 bloqueado
# Processo 6501 entrou em execução via AP
# Processo 6501 pronto
# Processo 6496 entrou em execução via BP
# Processo 6496 foi para IO
# Processo 6496 colocou IO na fila
# Processo 6496 bloqueado
# Processo 6496 pronto
# Processo 6505 entrou em execução via BP
# Processo 6505 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6496 pronto
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6498 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 pronto
# Processo 6496 entrou em execução via BP
# Processo 6496 foi para IO
# Processo 6496 colocou IO na fila
# Processo 6496 bloqueado
# Processo 6505 entrou em execução via BP
# Processo 6505 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 foi para IO
# Processo 6502 colocou IO na fila
# Processo 6502 bloqueado
# Processo 6502 pronto
# Processo 6496 pronto
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6502 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 foi para IO
# Processo 6498 colocou IO na fila
# Processo 6498 bloqueado
# Processo 6498 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 foi para IO
# Processo 6501 colocou IO na fila
# Processo 6501 bloqueado
# Processo 6496 entrou em execução via BP
# Processo 6496 foi para IO
# Processo 6496 colocou IO na fila
# Processo 6496 bloqueado
# Processo 6496 bloqueado
# Processo 6496 bloqueado
# Processo 6496 pronto
# Processo 6498 pronto
# Processo 6496 entrou em execução via BP
# Processo 6496 foi para IO
# Processo 6496 colocou IO na fila
# Processo 6496 pronto
# Processo 6505 entrou em execução via BP
# Processo 6505 pronto
# Processo 6496 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 foi para IO
# Processo 6503 colocou IO na fila
# Processo 6503 bloqueado
# Processo 6503 bloqueado
# Processo 6503 pronto
# Processo 6496 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6496 entrou em execução via BP
# Processo 6496 terminado
# Processo 6503 pronto
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6501 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 pronto
# Processo 6496 terminado
# Processo 6498 entrou em execução via BP
# Processo 6498 foi para IO
# Processo 6498 colocou IO na fila
# Processo 6498 bloqueado
# Processo 6498 pronto
# Processo 6496 terminado
# Processo 6505 entrou em execução via BP
# Processo 6505 pronto
# Processo 6498 pronto
# Processo 6496 terminado
# Processo 6503 entrou em execução via BP
# Processo 6503 foi para IO
# Processo 6503 colocou IO na fila
# Processo 6503 bloqueado
# Processo 6496 terminado
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6503 pronto
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 foi para IO
# Processo 6502 colocou IO na fila
# Processo 6502 bloqueado
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6502 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 foi para IO
# Processo 6498 colocou IO na fila
# Processo 6498 bloqueado
# Processo 6498 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 pronto
# Processo 6498 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6505 entrou em execução via BP
# Processo 6505 pronto
# Processo 6498 entrou em execução via BP
# Processo 6498 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 pronto
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 foi para IO
# Processo 6504 colocou IO na fila
# Processo 6504 bloqueado
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 pronto
# Processo 6502 entrou em execução via BP
# Processo 6502 terminado
# Processo 6498 entrou em execução via BP
# Processo 6498 terminado
# Processo 6498 terminado
# Processo 6501 entrou em execução via BP
# Processo 6501 pronto
# Processo 6498 terminado
# Processo 6501 entrou em execução via BP
# Processo 6501 foi para IO
# Processo 6501 colocou IO na fila
# Processo 6501 bloqueado
# Processo 6501 pronto
# Processo 6498 terminado
# Processo 6505 entrou em execução via BP
# Processo 6505 terminado
# Processo 6498 terminado
# Processo 6503 entrou em execução via BP
# Processo 6503 foi para IO
# Processo 6503 colocou IO na fila
# Processo 6503 bloqueado
# Processo 6503 pronto
# Processo 6501 pronto
# Processo 6503 entrou em execução via BP
# Processo 6503 pronto
# Processo 6503 entrou em execução via AP
# Processo 6503 terminado
# Processo 6502 terminado
# Processo 6503 terminado
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6502 terminado
# Processo 6502 terminado
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 pronto
# Processo 6501 entrou em execução via BP
# Processo 6501 terminado
# Processo 6503 terminado
# Processo 6501 terminado
# Processo 6503 terminado
# Processo 6499 entrou em execução via BP
# Processo 6499 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6501 terminado
# Processo 6499 entrou em execução via BP
# Processo 6499 terminado
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 foi para IO
# Processo 6500 colocou IO na fila
# Processo 6500 bloqueado
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6504 entrou em execução via BP
# Processo 6504 terminado
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6504 terminado
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 pronto
# Processo 6500 entrou em execução via BP
# Processo 6500 terminado
# Processo 6497 entrou em execução via BP
# Processo 6497 pronto
# Processo 6500 terminado
# Processo 6497 entrou em execução via BP
# Processo 6497 terminado
#     6496 6497 6498 6499 6500 6501 6502 6503 6504 6505
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7                     E
# 8      P              E
# 9      P              E
# 10     E              P
# 11     E              P
# 12     E              P
# 13     E              P
# 14     E              P                             P
# 15     P              P                   P         E
# 16     P              P                   P         E
# 17     P              P                   P         E
# 18     P              P                   P         E
# 19     P              P                   P         E
# 20     P              P                   E         P
# 21     P              P              P    E         P
# 22     P              P              P    E         P
# 23     P              P              P    E         P
# 24     P              P              P    E         P
# 25     P              P              E    P         P
# 26     P              P              E    P         P
# 27     P              P              E    P         P
# 28     P              P              B    P         P
# 29     P              P              B    P         P
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 776    T    P    T    T    E    T    T    T    T    T
# 777    T    P    T    T    E    T    T    T    T    T
# 778    T    P    T    T    E    T    T    T    T    T
# 779    T    P    T    T    E    T    T    T    T    T
# 780    T    E    T    T    P    T    T    T    T    T
# 781    T    E    T    T    P    T    T    T    T    T
# 782    T    E    T    T    P    T    T    T    T    T
# 783    T    E    T    T    P    T    T    T    T    T
# 784    T    E    T    T    P    T    T    T    T    T
# 785    T    P    T    T    E    T    T    T    T    T
# 786    T    P    T    T    E    T    T    T    T    T
# 787    T    P    T    T    E    T    T    T    T    T
# 788    T    P    T    T    E    T    T    T    T    T
# 789    T    P    T    T    E    T    T    T    T    T
# 790    T    P    T    T    E    T    T    T    T    T
# 791    T    P    T    T    E    T    T    T    T    T
# 792    T    P    T    T    E    T    T    T    T    T
# 793    T    E    T    T    T    T    T    T    T    T
# 794    T    E    T    T    T    T    T    T    T    T
# 795    T    P    T    T    T    T    T    T    T    T
# 796    T    P    T    T    T    T    T    T    T    T
# 797    T    P    T    T    T    T    T    T    T    T
# 798    T    P    T    T    T    T    T    T    T    T
# 799    T    P    T    T    T    T    T    T    T    T
# 800    T    E    T    T    T    T    T    T    T    T
# 801    T    E    T    T    T    T    T    T    T    T
# 802    T    E    T    T    T    T    T    T    T    T
# 803    T    E    T    T    T    T    T    T    T    T
# 804    T    E    T    T    T    T    T    T    T    T
# 805    T    T    T    T    T    T    T    T    T    T
#
# [806 rows x 10 columns]

# %%
new_df = log_data_df.style.apply(lambda x: ["background: red" if v == "E" else "" for v in x], axis = 1)
new_df
# Out:
# <style  type="text/css" >
#     #T_b40dcddc_70d3_11e9_82a0_80e65011548erow7_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow8_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow9_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow10_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow11_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow12_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow13_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow14_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow15_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow16_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow17_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow18_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow19_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow20_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow21_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow22_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow23_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow24_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow25_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow26_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow27_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow30_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow31_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow32_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow33_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow34_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow35_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow36_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow37_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow38_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow39_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow40_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow41_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow42_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow43_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow44_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow45_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow46_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow47_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow48_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow49_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow55_col2 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow56_col5 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow57_col5 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow58_col5 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow59_col5 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow60_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow61_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow62_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow63_col0 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow65_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow66_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow67_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow68_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow69_col9 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow70_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow71_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow72_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow73_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow74_col7 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow75_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow76_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow77_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow78_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow79_col6 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow85_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow86_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow87_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow88_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow89_col3 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow90_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow91_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow92_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow93_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow94_col8 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow95_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow96_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow97_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow98_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow99_col4 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow100_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow101_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow102_col1 {
#             background:  red;
#         }    #T_b40dcddc_70d3_11e9_82a0_80e65011548erow103_col1 {
#             background:  red;

# %%
new_df_trans = log_data_df.T
new_df_trans_color = new_df_trans.style.apply(lambda x: ["background: red" if v == "E" else "" for v in x], axis = 1)
new_df_trans_color
# Out:
# <style  type="text/css" >
#     #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col10 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col11 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col12 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col13 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col14 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col60 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col61 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col62 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col63 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col125 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col126 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col127 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col186 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col205 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col206 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col235 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col236 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col237 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col238 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow0_col239 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col45 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col46 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col47 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col48 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col49 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col100 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col101 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col102 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col103 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col104 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col165 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col166 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col167 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col168 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col169 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col265 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col266 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col267 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col268 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col269 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col370 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col371 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col372 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col373 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col374 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col475 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col476 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col477 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col478 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col479 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col575 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col576 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col577 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col578 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col579 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col620 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col621 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col622 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col623 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col624 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col645 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col646 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col647 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col648 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col649 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col665 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col666 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col667 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col668 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col669 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col685 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col686 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col687 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col688 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col689 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col705 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col706 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col707 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col708 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col709 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col730 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col731 {
#             background:  red;
#         }    #T_bb1dfd72_70d3_11e9_82a0_80e65011548erow1_col732 {
#             background:  red;
#         }    #T_bb1dfd72_70d3
